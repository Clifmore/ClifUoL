# %% [markdown]
# # Welcome to ClifUoL Project!## Jupyter Notebook with Git IntegrationThis notebook demonstrates your setup with:- **Python** data analysis environment- **Jupyter** notebook interface- **Git** version control- **GitHub** integration### Getting Started:1. Run cells with **Shift+Enter**2. Save with **Ctrl+S**3. Use Git panel in JupyterLab sidebar---**User:** Clifmore**Repository:** https://github.com/Clifmore/ClifUoL

# %%
# Test Python environment
import sys
print("Python version:", sys.version)
print("\nJupyter + Git setup successful!")
print("Project: ClifUoL")
print("User: Clifmore")

# %%
# Test data science libraries
try:
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    print("✓ Pandas version:", pd.__version__)
    print("✓ NumPy version:", np.__version__)
    print("\nAll libraries loaded successfully!")
except ImportError as e:
    print("Missing library:", e)
    print("Install with: pip install pandas numpy matplotlib")

# %% [markdown]
# ## Git Workflow### In JupyterLab:1. Click **Git icon** in left sidebar2. **Stage** changes by clicking '+'3. **Commit** with a message4. **Push** to GitHub### From Command Line:```bash
# cd C:\Dev\ClifUoL
# git add .
# git commit -m "Updated analysis"
# git push
# ```
